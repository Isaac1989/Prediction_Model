# %%
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
import pandas as pd
import numpy as np
import os

# %matplotlib inline

path = '/'.join(os.getcwd().split('/')[:-1])
print(path)
# Out:
# /Volumes/Dropbox/largetransfer/luc/carter

# %%
tci = pd.read_csv(path+'/data/model_data/tci_2_2.csv', dtype={'Parcel ID':str})
ppns = set(tci['ppn'])
ppns_num = set(tci['ppn'].apply(lambda x: x.replace('-','')))
print(tci.shape)
# Out:
# (113051, 63)

# %%
fc = pd.read_csv(path+'/data/clean_data/foreclosure_filings2.csv', parse_dates=[2])

fc = fc.sort_values('filedate').groupby('caseno').last()
fc = fc.set_index('parcel')
fc = fc.rename(columns={'filedate':'date'})
fc['type'] = 'fc'
fc = fc[['date','type']]

# %%
fc.head(2)
# Out:
#                  date type
# parcel
# 120-20-030 2006-10-03   fc
# 107-16-046 2006-10-03   fc

# %%
sa.head()
# Out:
#        parcel                address    salesdt  saleno  sold_amt appraisal  \
# 0  001-02-016  11436 EDGEWATER DRIVE 2009-08-24      46       NaN  $225,000
# 1  001-02-016  11436 EDGEWATER DRIVE 2009-11-23      78       NaN  $225,000
# 2  001-02-016  11436 EDGEWATER DRIVE 2010-07-06      61       NaN  $200,000
# 3  001-02-016  11436 EDGEWATER DRIVE 2010-10-25      45       NaN  $200,000
# 4  001-02-020  11315 EDGEWATER DRIVE 2013-03-11     600  $175,000        $0
#
#      minbid     scaseno             withdrawn  \
# 0  $150,000  CV08664602  Withdrawn - Order of
# 1  $150,000  CV08664602  Withdrawn - Order of
# 2  $133,334  CV08664602  Withdrawn - Order of
# 3  $133,334  CV08664602  Withdrawn - Order of
# 4  $100,521  CV09684820                SOLD -
#
#                                            plaintiff    ...      \
# 0              INDYMAC BANK FSB C/O INDYMAC BANK FSB    ...
# 1              INDYMAC BANK FSB C/O INDYMAC BANK FSB    ...
# ...

# %%
sa = pd.read_csv(path+'/data/clean_data/sheriff_auction.csv', parse_dates=[2], encoding="ISO-8859-1")

sa = sa.sort_values('salesdt').groupby('parcel').last()
sa = sa.rename(columns={'salesdt':'date'})
sa = sa[['date']]
sa['type'] = 'sa'

# %%
al.groupby('')
# Out:
# Index(['AMOUNT_PAID', 'ASSUMED_LOAN_AMOUNT', 'AUTO_FILE_NUMBER',
#        'BUILDINGS_ON_LAND', 'CAMA_INV_FILE', 'CAMA_SALE_FILE',
#        'CHANGE_TIMESTAMP', 'CONVEYANCE_FEE', 'DEED_TYPE', 'EXEMPTCODE',
#        'EXEMPTCODE_DESCR', 'FEE_CHECK_NUM', 'FEE_PAID_BY', 'GIFT', 'GRANTEE1',
#        'GRANTOR1', 'GRANTOR_IS_MORTGAGEE', 'GRANTOR_IS_RELATIVE',
#        'INSTRUMENT_DATE', 'INSTRUMENT_TYPE', 'LAND_CONTRACT', 'LEASED_FEE',
#        'LEASE_HOLD', 'LIFE_ESTATE', 'MINERAL_RIGHTS_RESERVED', 'MONTH_OF_SALE',
#        'MOTHER', 'NUMBER_OF_PROPERTIES_IN_SALE', 'PARTINTER_EST_TRANSFERRED',
#        'PERMISSIVE_FEE', 'PERSONAL_PROPERTY_AMOUNT', 'PROPERTY_NUMBER',
#        'RECEIPT_NUMBER', 'RECORDED_BOOK', 'RECORDED_DATE', 'RECORDED_PAGE',
#        'SALES_AMOUNT', 'SALES_SOURCE', 'SALES_SOURCE_DESCR', 'SALE_VALID',
#        'TRADE', 'mdate', 'TRANSFER_FEE', 'TRANSFER_FROM_PARCEL',
#        'TRANSFER_HISTORY_ID', 'TRANSFER_NUMBER', 'TRANSFER_ORDER',
# ...

# %%
al = pd.read_csv(path+'/data/clean_data/armslength.csv')
al = al.drop_duplicates()

months = dict(zip(['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC'],range(1,13)))

def parse_date(x):
    day = int(x[0:2])
    month = months[x[2:5]]
    year = int(x[5:])
    return dt.date(year,month,day)

al['date'] = al.mdate.apply(parse_date)
al = al[al.date < dt.date(2015,6,1)]
# Out:
# //anaconda/envs/vacancy/lib/python3.4/site-packages/IPython/core/interactiveshell.py:2902: DtypeWarning: Columns (2,10,32,33,35,38,55,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
t = pd.read_csv(path+'/data/clean_data/transfers.csv', parse_dates=['mdate'])
# Out:
# //anaconda/envs/vacancy/lib/python3.4/site-packages/IPython/core/interactiveshell.py:2902: DtypeWarning: Columns (4,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-d05e1762a4a1> in <module>()
# ----> 1 fc = fc.sort_values('filedate').groupby('caseno').last()
#       2 fc = fc.set_index('parcel')
#
# //anaconda/envs/vacancy/lib/python3.4/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze)
#    3322         axis = self._get_axis_number(axis)
#    3323         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
# -> 3324                        sort=sort, group_keys=group_keys, squeeze=squeeze)
#    3325
#    3326     def asfreq(self, freq, method=None, how=None, normalize=False):
#
# //anaconda/envs/vacancy/lib/python3.4/site-packages/pandas/core/groupby.py in groupby(obj, by, **kwds)
#    1250         raise TypeError('invalid type: %s' % type(obj))
#    1251
# -> 1252     return klass(obj, by, **kwds)
# ...

# %%
fc[['parcel','filedate']]
# Out:
#                   parcel   filedate
# caseno
# BR-06-000001  120-20-030 2006-10-03
# BR-06-000005  107-16-046 2006-10-03
# BR-06-000007  123-23-077 2006-10-03
# BR-06-000008  001-09-098 2006-10-03
# BR-06-000010  121-19-100 2006-10-03
# BR-06-000013  005-29-032 2006-10-03
# BR-06-000015  108-15-083 2006-10-03
# BR-06-000017  115-10-049 2006-10-03
# BR-06-000018  119-01-007 2006-10-03
# BR-06-000020  006-07-038 2006-10-03
# BR-06-000021  006-26-142 2006-10-03
# BR-06-000022  121-33-110 2006-10-03
# BR-06-000028  130-11-109 2006-10-03
# BR-06-000029  010-18-001 2006-10-03
# BR-06-000032  125-33-046 2006-10-03
# BR-06-000037  006-04-138 2006-10-03
# BR-06-000041  133-07-044 2006-10-03
# BR-06-000042  115-22-007 2006-10-03
# BR-06-000043  104-21-066 2006-10-03
# BR-06-000046  118-07-094 2006-10-03
# BR-06-000047  125-33-066 2006-10-03
# BR-06-000048  134-22-111 2006-10-03
# BR-06-000060  136-02-041 2006-10-04
# BR-06-000061  129-19-116 2006-10-04
# BR-06-000062  104-18-050 2006-10-04
# ...
