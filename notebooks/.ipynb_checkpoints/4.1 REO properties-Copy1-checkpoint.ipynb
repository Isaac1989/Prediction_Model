# %% [markdown]
# # Analysis of vacancy and foreclosures, transactions, sheriff's auctions, and armslength sales

# %%
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
import pandas as pd
import numpy as np
import os

# %matplotlib inline

path = '/'.join(os.getcwd().split('/')[:-1])
print(path)
# Out:
# /Volumes/Dropbox/largetransfer/luc/carter

# %%
df = pd.read_csv(path+'/data/model_data/tci_2_0.csv', index_col = 0)
tci = pd.read_csv(path+'/data/model_data/tci_2_2.csv', parse_dates=['Date'], dtype={'Parcel ID':str})
tci = pd.merge(tci, df[['NAME10','SPA_NAME']], how='left', right_index=True, left_on='parcel')
ppns = set(tci['parcel'])
dates = dict(zip(tci.parcel, tci.Date))
print(tci.shape)
# Out:
# (113132, 39)

# %% [markdown]
# ## Foreclosures

# %%
fc = pd.read_csv(path+'/data/clean_data/foreclosure_filings2.csv', parse_dates=[2])
fc = fc.sort_values('filedate').groupby('caseno').last()
fc = fc.rename(columns={'filedate':'date'}).reset_index()

fc.columns
# Out:
# Index([u'caseno', u'parcel', u'status', u'date', u'defendant',
#        u'parcel_address', u'dateid', u'case_title', u'plaintiff', u'FORE',
#        u'LATITUDE', u'LONGITUDE', u'zip_fore'],
#       dtype='object')

# %%
fc_parcel = set(fc.parcel)
tci['fc'] = tci.apply(lambda x: x.parcel in fc_parcel, axis=1)
pd.crosstab(tci.fc, tci.vacant)
# Out:
# vacant      0     1
# fc
# False   79154  3836
# True    23940  6202

# %%
sum(tci.vacant), sum(tci.fc)
# Out:
# (10038, 30142)

# %% [markdown]
# #### Has it been foreclosed before?
#
# So of the 30,142 parcels that have been foreclosed between 1/3/2006 and 11/6/2015, 6,202 are currently vacant, of the 10,038 total residential vacancies as measured by TCI. This means that 3,836 parcels were determined to be vacancy but never have been foreclosed.

# %%
fc_parcel = set(fc[fc.status=='Inactive'].parcel)
tci['fc'] = tci.apply(lambda x: x.parcel in fc_parcel, axis=1)
pd.crosstab(tci.fc, tci.vacant)
# Out:
# vacant      0     1
# fc
# False   79967  4135
# True    23127  5903

# %%
fc_parcel = set(fc[fc.status=='Active'].parcel)
tci['fc'] = tci.apply(lambda x: x.parcel in fc_parcel, axis=1)
pd.crosstab(tci.fc, tci.vacant)
# Out:
# vacant       0     1
# fc
# False   101689  9455
# True      1405   583

# %%
tem = pd.merge(fc[['parcel','status']].groupby('parcel').count(), tci[['parcel','vacant']], how='right', left_index=True, right_on='parcel').fillna(0)
tem = tem[['status','vacant']].groupby('status').agg([sum,len])
tem['percent'] = tem.vacant['sum']/tem.vacant['len']
tem.T
# Out:
# status                  0             1            2            3           4  \
# vacant  sum   3836.000000   4193.000000  1579.000000   330.000000   81.000000
#         len  82990.000000  22045.000000  6255.000000  1422.000000  326.000000
# percent          0.046222      0.190202     0.252438     0.232068    0.248466
#
# status               5          6      7
# vacant  sum  14.000000   4.000000  1.000
#         len  71.000000  15.000000  8.000
# percent       0.197183   0.266667  0.125

# %% [markdown]
# ## Sheriff's Auctions

# %%
sa = pd.read_csv(path+'/data/clean_data/sheriff_auction.csv', parse_dates=[2], encoding="ISO-8859-1")

# %%
reo = pd.read_csv(path+'/data/extra_data/reo.csv', encoding="utf-8")
reo = reo.groupby('GRANTEE1').last()

# %%
purchaser = sa.groupby('scaseno').last().groupby('purchaser').count().sort_values('parcel',ascending=False)[['parcel']]
purchaser = purchaser.rename(columns={'parcel':'purchaser_count'})
sa = pd.merge(sa, purchaser, how='left', left_on='purchaser',right_index=True)
# sa = sa.sort_values('salesdt').groupby('parcel').last()
sa = sa.rename(columns={'salesdt':'date'})
# sa = sa[['date','plaintiff_count']]
# sa['type'] = 'sa'
# sa = sa.reset_index()
sa['purchaser_count'] = sa['purchaser_count'].fillna(0)
sa.columns
# Out:
# Index([         u'parcel',         u'address',            u'date',
#                 u'saleno',        u'sold_amt',       u'appraisal',
#                 u'minbid',         u'scaseno',       u'withdrawn',
#              u'plaintiff',         u'sdefend',       u'purchaser',
#               u'paddress',          u'rparty',        u'raddress',
#               u'attorney',        u'descript',        u'location',
#             u'defend_att',            u'with',          u'status',
#                  u'ssold',             u'SHF',        u'LATITUDE',
#              u'LONGITUDE', u'purchaser_count'],
#       dtype='object')

# %%
# al = pd.read_csv(path+'/data/clean_data/armslength.csv',dtype=str)
# al = al.drop_duplicates()

# months = dict(zip(['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC'],range(1,13)))

# def parse_date(x):
#     day = int(x[0:2])
#     month = months[x[2:5]]
#     year = int(x[5:])
#     return dt.datetime(year,month,day)

# al['date'] = al.mdate.apply(parse_date)
# # al = al[al.date < dt.datetime(2015,6,1)]

# al = al.rename(columns={'PROPERTY_NUMBER':'parcel'})
# al = al[['date','parcel']]
# al['type'] = 'al'
# al['plaintiff_count'] = 0

# %%
t2 = pd.read_csv(path+'/data/clean_data/transfers.csv', parse_dates=['mdate'], dtype=str)

# %%
t = pd.read_csv(path+'/data/clean_data/transfers.csv', parse_dates=['mdate'], dtype=str)

t = t.rename(columns={'PROPERTY_NUMBER':'parcel','mdate':'date'})
t['type'] = 't'
t['REO'] = 0

# %%
t = pd.merge(t, reo, how='left',left_on='GRANTEE1', right_index=True)

# %%
t.loc[(t.DEED_TYPE.isin(['Sheriffs Deed',
 'Sheriffs Deed Ex'])),'REO'] = 1

# %%
temp = tci[tci.parcel.isin(t[(t.REO==1)&(t.date > dt.datetime(2013,1,1))].parcel)]
sum(temp.vacant), len(temp)
# Out:
# (930, 3581)

# %%
fc2 = fc[['date','parcel']]
fc2['type'] = 'fc'
fc2['REO'] = 0
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
sa2 = sa[['date','parcel','sold_amt']]
sa2['REO'] = 0
sa2['type'] = 'sa'
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
df = fc2.append(sa2.loc[sa2.sold_amt.notnull(),['date','REO','parcel','type']]).append(t)
df = df.sort_values('date')
df = df.loc[df.apply(lambda x: x.date < dates[x.parcel], axis=1)]

# %%
last = df.groupby('parcel').last()
sub = last[(last['type'] == 'sa')]#&(last['plaintiff_count']>-1)]

# %%
t = tci[tci.parcel.isin(sa[sa.REO].parcel)].vacant
sum(t),len(t)

# %%
test = set(last[(last['type'] == 'sa') & (last['REO']==True)].index)
sum(tci[tci.parcel.isin(test)].vacant), len(tci[tci.parcel.isin(test)].vacant)

# %%
test = set(sub.index)
sum(tci[tci.parcel.isin(test)].vacant), len(tci[tci.parcel.isin(test)].vacant)

# %%
import re

def find_REO(s):
    if isinstance(s,str) or isinstance(s,unicode):
        s = s.lower()
        if re.search("llc", s):
            return True
        if re.search("bank", s):
            return True
        if re.search("mortg", s):
            return True
        if re.search("mort.", s):
            return True
        if re.search("comp", s):
            return True
        if re.search("corp", s):
            return True
        if re.search("fannie", s):
            return True
        if re.search("housing", s):
            return True
        if re.search("sec.", s):
            return True
        if re.search("loan", s):
            return True
        return False
    else:
        return False

# %%
sa.groupby('purchaser').count().sort_values('date',ascending=False)

# %%
sa['REO'] = sa.purchaser.apply(find_REO)

# %%
find_REO(sa.purchaser.iloc[6])
# Out:
# True

# %%
s = sa.groupby('scaseno').last()

# %%
s
# Out:
#                          parcel  \
# scaseno
# 05CV19450            002-23-014
# 06CV027418           133-02-049
# 07CVH13068           008-15-044
# 08CVH06194           118-29-064
# 163,708 PLURIES      110-14-095
# 178,329 2ND PLURIES  116-26-016
# 178,329 3RD PLURIES  116-26-016
# 2007CVH18584         017-29-127
# 2008CVH30738         119-29-122
# 209,622 2ND PLURIES  109-14-121
# 209,622 PLURIES      109-14-121
# 227,494 PLURIES      014-20-121
# 235,476 2ND PLURIES  129-06-080
# 238,634 PLURIES      139-11-110
# 240,925 ALIAS        138-24-038
# 243,961 4TH PLURIES  137-21-064
# 247,504              019-19-068
# 249,337 PLURIES      115-02-063
# 253,810 4TH PLURIES  129-30-082
# 254,070              017-28-199
# 255,828 2ND PLURIES  117-08-049
# 255,828 3RD PLURIES  117-08-049
# 255,828 4TH PLURIES  117-08-049
# 255,828 5TH PLURIES  117-08-049
# 255,828 6TH PLURIES  117-08-049
# 256,449 ALIAS        134-14-117
# 262,104 3RD PLURIES  140-01-101
# 266,292 2ND PLURIES  018-11-062
# 267,418 2ND PLURIES  117-16-096
# 267,546 2ND PLURIES  127-24-156
# ...                         ...
# CV15846273           114-21-077
# CV15846698           005-30-042
# CV15846757           009-28-008
# CV15846886           137-24-074
# CV15846970           133-20-114
# CV15847127           005-30-088
# CV15847556           129-29-132
# CV15847654           018-06-067
# CV15848045           027-04-092
# CV15848328           022-14-046
# CV93254070           017-28-199
# CV97341177           016-12-024
# CV97345013           016-09-077
# CV98354337           139-14-042
# CV98354477           014-07-025
# CV98360458           143-13-047
# CV98360731           129-24-078
# CV98361485           141-21-002
# CV98370749           141-15-057
# CV98371457           119-01-043
# CV99373300           128-14-030
# CV99373484           115-28-060
# CV99380061           117-22-053
# CV99383983           120-03-033
# CV99386629           005-24-102
# CV99387728           111-06-122
# CV99390425           130-17-105
# CV99397370           139-19-035
# CV99398582           135-10-089
# CVH 24907            107-12-173
#
#                                                                address  \
# scaseno
# 05CV19450                                         6909 FRANKLIN AVENUE
# CV99383983                                      1378 EAST 114TH STREET
# CV99386629                                       3111 WEST 96TH STREET
# CV99387728                                   436-438 EAST 120TH STREET
# CV99390425                                      3353 EAST 147TH STREET
# CV99397370                                      3724 EAST 153RD STREET
# CV99398582                                          3555 EAST 108TH ST
# CVH 24907                                               1346  ANSEL RD
#
#                           date  saleno sold_amt appraisal   minbid  \
# scaseno
# 05CV19450           2009-04-20     804  $43,000   $45,000  $30,000
# 06CV027418          2009-04-20     803     $334      $500     $334
# 07CVH13068          2010-06-14     800  $30,000   $45,000  $30,000
# 08CVH06194          2009-06-15     800  $23,334   $35,000  $23,334
# 163,708 PLURIES     2001-03-19      17      NaN   $50,000  $33,333
# 178,329 2ND PLURIES 2002-10-21       9  $16,000   $24,000  $16,000
# 178,329 3RD PLURIES 2004-03-01      20  $16,000   $24,000  $16,000
# 2007CVH18584        2008-11-17     800  $33,334   $50,000  $33,334
# 2008CVH30738        2010-01-25     800  $26,667   $40,000  $26,667
# 209,622 2ND PLURIES 2004-08-30      31  $20,000   $30,000  $20,000
# 209,622 PLURIES     2002-05-20      33  $22,667   $34,000  $22,667
# 227,494 PLURIES     2000-06-26      30      NaN   $55,000  $36,667
# 235,476 2ND PLURIES 2001-01-02      13  $80,000   $95,000  $63,333
# 238,634 PLURIES     2002-06-03       9  $46,200   $53,200  $35,467
# 240,925 ALIAS       2004-09-20      14      NaN   $65,000  $43,334
# 243,961 4TH PLURIES 2001-05-21      13      NaN   $55,000  $36,667
# 247,504             2006-05-22     162  $33,334       NaN      NaN
# 249,337 PLURIES     2000-06-26       9      NaN   $48,000  $32,000
# 253,810 4TH PLURIES 2000-08-28      21  $36,205   $42,000  $28,000
# 254,070             2006-04-24      93      NaN       NaN      NaN
# 255,828 2ND PLURIES 2003-04-14      33      NaN   $60,000  $39,600
# 255,828 3RD PLURIES 2004-08-02      42      NaN   $66,000  $44,000
# 255,828 4TH PLURIES 2005-06-27      51      NaN   $66,000  $44,000
# 255,828 5TH PLURIES 2005-10-17      38      NaN   $66,000  $44,000
# 255,828 6TH PLURIES 2006-03-27      55  $20,000       NaN      NaN
# 256,449 ALIAS       2001-03-19      22  $34,200   $45,000  $30,000
# 262,104 3RD PLURIES 2002-03-18      20      NaN   $60,000  $40,000
# 266,292 2ND PLURIES 2001-05-21      38      NaN   $70,000  $46,667
# 267,418 2ND PLURIES 2000-11-06      22  $45,000   $60,000  $40,000
# 267,546 2ND PLURIES 2002-12-02      21  $40,000   $60,000  $39,600
# ...                        ...     ...      ...       ...      ...
# CV15846273          2015-11-16       6      NaN   $25,000  $16,667
# CV15846698          2015-12-07      32      NaN   $40,000  $26,667
# CV15846757          2015-10-26      27  $30,000   $40,000  $26,667
# CV15846886          2015-12-07      23      NaN   $18,000  $12,000
# CV15846970          2015-12-07      20      NaN   $15,000  $10,000
# CV15847127          2015-11-23      15      NaN   $15,000  $10,000
# CV15847556          2015-11-30       5      NaN    $7,000   $4,667
# CV15847654          2015-12-07      40      NaN   $30,000  $20,000
# CV15848045          2015-12-07      46      NaN   $55,000  $36,667
# CV15848328          2015-12-07      43      NaN   $45,000  $30,000
# CV93254070          2010-03-15      55      NaN   $40,000  $26,667
# CV97341177          2008-09-08      93      NaN   $25,000  $16,667
# CV97345013          2007-09-10     113      NaN   $38,000  $25,334
# CV98354337          2007-07-09       8  $53,334       NaN      NaN
# CV98354477          2007-11-26     112      NaN   $60,000  $40,000
# CV98360458          2007-07-23      72  $30,000       NaN      NaN
# CV98360731          2007-09-10      13      NaN   $30,000  $20,000
# CV98361485          2008-02-04      33  $50,000   $75,000  $50,000
# CV98370749          2009-06-29       4      NaN   $45,000  $30,000
# CV98371457          2007-04-02      82  $52,180       NaN      NaN
# CV99373300          2007-05-14       3  $33,334       NaN      NaN
# CV99373484          2008-04-21      39      NaN   $45,000  $30,000
# CV99380061          2007-07-09      93      NaN       NaN      NaN
# CV99383983          2009-02-02      33      NaN   $22,000  $14,667
# CV99386629          2007-06-11     160  $26,667       NaN      NaN
# CV99387728          2008-05-19      58  $26,667   $20,000  $13,334
# CV99390425          2007-04-16     131  $43,334       NaN      NaN
# CV99397370          2007-08-27      38  $30,000   $45,000  $30,000
# CV99398582          2007-06-04     101      NaN       NaN      NaN
# CVH 24907           2013-12-16     800   $5,000    $3,500   $2,334
#
#                                 withdrawn  \
# scaseno
# 05CV19450                             NaN
# 06CV027418                            NaN
# 07CVH13068                            NaN
# 08CVH06194                            NaN
# 163,708 PLURIES                       NaN
# 178,329 2ND PLURIES                   NaN
# 178,329 3RD PLURIES                   NaN
# 2007CVH18584                          NaN
# 2008CVH30738                          NaN
# 209,622 2ND PLURIES                   NaN
# 209,622 PLURIES                       NaN
# 227,494 PLURIES                BANKRUPTCY
# 235,476 2ND PLURIES                   NaN
# 238,634 PLURIES                       NaN
# 240,925 ALIAS          ORDER of the COURT
# 243,961 4TH PLURIES                   NaN
# 247,504                               NaN
# 249,337 PLURIES                BANKRUPTCY
# 253,810 4TH PLURIES                   NaN
# 254,070                      BANKRUPTCYÂ
# 255,828 2ND PLURIES            BANKRUPTCY
# 255,828 3RD PLURIES            BANKRUPTCY
# 255,828 4TH PLURIES                NO BID
# 255,828 5TH PLURIES                NO BID
# 255,828 6TH PLURIES                   NaN
# 256,449 ALIAS                         NaN
# 262,104 3RD PLURIES                   NaN
# 266,292 2ND PLURIES            BANKRUPTCY
# 267,418 2ND PLURIES                   NaN
# 267,546 2ND PLURIES                   NaN
# ...                                   ...
# CV15846273                            NaN
# CV15846698                            NaN
# CV15846757                            NaN
# CV15846886                            NaN
# CV15846970                            NaN
# CV15847127                            NaN
# CV15847556                            NaN
# CV15847654                            NaN
# CV15848045                            NaN
# CV15848328                            NaN
# CV93254070           Withdrawn - Order of
# CV97341177           Withdrawn - Order of
# CV97345013           Withdrawn - Order of
# CV98354337                            NaN
# CV98354477           Withdrawn - Order of
# CV98360458                            NaN
# CV98360731           Withdrawn - Not Sold
# CV98361485           Withdrawn - Bankrupt
# CV98370749           Withdrawn - Bankrupt
# 255,828 3RD PLURIES                                JAMES POGRAS, ET AL  ...
# 255,828 4TH PLURIES                                JAMES POGRAS, ET AL  ...
# 255,828 5TH PLURIES                                JAMES POGRAS, ET AL  ...
# 255,828 6TH PLURIES                                JAMES POGRAS, ET AL  ...
# 256,449 ALIAS                              JOHN J. HONAKER, JR., ET AL  ...
# 262,104 3RD PLURIES                             ANDREA N. MOORE, ET AL  ...
# 266,292 2ND PLURIES                            CHARLES H. BROWN, ET AL  ...
# 267,418 2ND PLURIES                               JASPER MULDROW, ETAL  ...
# 267,546 2ND PLURIES                       JOSEPH W. TAYLOR, JR., ET AL  ...
# ...                                                                ...  ...
# CV15846273                                              JACKSON/AARON/  ...
# CV15846698                                                 DONES/JOSE/  ...
# CV15846757                                            PURKEY/CONNIE/E.  ...
# CV15846886                                              EDDY/FELICIA/M  ...
# CV15846970                                           SHAHEED/SULAIMAN/  ...
# CV15847127                                            RAMEY/RAYMOND/L.  ...
# CV15847556                                           BARRETT/RICHARD/D  ...
# CV15847654                                               CUCCI/ANGELO/  ...
# CV15848045                                           KOENIG/ALEXANDER/  ...
# CV15848328                                                COLE/KYLE/W.  ...
# CV93254070                                   KENNETH D. SANNEY, ET AL.  ...
# CV97341177                                     ALICE J TIEDJEN, ET AL.  ...
# CV97345013                                        CHARLES ADAMS, ET AL  ...
# CV98354337              BERTHA YARBROUGH AKA BERTHA GLOVE-ET AL, ET AL  ...
# CV98354477                                     RAYMOND H METTS, et al.  ...
# CV98360458                                    WALTER LEE BLACK, ET AL.  ...
# CV98360731                                       KENNETH GOLSTON ET AL  ...
# CV98361485                                        WILLIAM JONES, ET AL  ...
# CV98370749            STANLEY HOWARD AKA STANLEY R HOWARD-ET AL, ET AL  ...
# CV98371457                            EAST-WEST PROPERTIES INC., ET AL  ...
# CV99373300                                     U C LENDING INC, ET AL.  ...
# CV99373484                                       KEITH C BREMER, ET AL  ...
# CV99380061                                          DAVID HARPER,ET AL  ...
# CV99383983                                       ARTHUR JOHNSON, ET AL  ...
# CV99386629                                          CESAR ROMAN, ET AL  ...
# CV99387728           M LA MARSEILLE DEMARCOS AKA ETC ,ET AL A LA DE...  ...
# CV99390425                                   MARLENE C JENKINS, ET AL.  ...
# CV99397370                                     ROSIE MAE FAISON, ET AL  ...
# CV99398582                                   EMMETT OSCAR LYNCH, ET AL  ...
# CVH 24907                                                 THOMAS/LISA/  ...
#
#                                     location defend_att   with  \
# scaseno
# 05CV19450                                NaN        NaN    NaN
# 06CV027418                               NaN        NaN    NaN
# 07CVH13068                               NaN        NaN    NaN
# 08CVH06194                               NaN        NaN    NaN
# 163,708 PLURIES      CLEVELAND East of River        NaN    NaN
# 178,329 2ND PLURIES  CLEVELAND East of River        NaN    NaN
# 178,329 3RD PLURIES  CLEVELAND East of River        NaN    NaN
# 2007CVH18584                             NaN        NaN    NaN
# 2008CVH30738                             NaN        NaN    NaN
# 209,622 2ND PLURIES  CLEVELAND East of River        NaN    NaN
# 209,622 PLURIES      CLEVELAND East of River        NaN    NaN
# 227,494 PLURIES      CLEVELAND West of River        NaN  BANKR
# 235,476 2ND PLURIES  CLEVELAND East of River        NaN    NaN
# 238,634 PLURIES      CLEVELAND East of River        NaN    NaN
# 240,925 ALIAS        CLEVELAND East of River        NaN  ORDER
# 243,961 4TH PLURIES  CLEVELAND East of River        NaN    NaN
# 247,504                                  NaN        NaN    NaN
# 249,337 PLURIES      CLEVELAND East of River        NaN  BANKR
# 253,810 4TH PLURIES  CLEVELAND East of River        NaN    NaN
# 254,070              CLEVELAND West of River        NaN  BANKR
# 255,828 2ND PLURIES  CLEVELAND East of River        NaN  BANKR
# 255,828 3RD PLURIES  CLEVELAND East of River        NaN  BANKR
# 255,828 4TH PLURIES  CLEVELAND East of River        NaN  NOBID
# 255,828 5TH PLURIES  CLEVELAND East of River        NaN  NOBID
# 255,828 6TH PLURIES  CLEVELAND East of River        NaN    NaN
# 256,449 ALIAS        CLEVELAND East of River        NaN    NaN
# 262,104 3RD PLURIES  CLEVELAND East of River        NaN    NaN
# 266,292 2ND PLURIES  CLEVELAND West of River        NaN  BANKR
# 267,418 2ND PLURIES  CLEVELAND East of River        NaN    NaN
# 267,546 2ND PLURIES  CLEVELAND East of River        NaN    NaN
# ...                                      ...        ...    ...
# CV15846273           CLEVELAND EAST OF THE R        NaN    NaN
# CV15846698           CLEVELAND WEST OF THE R        NaN    NaN
# CV15846757           CLEVELAND WEST OF THE R        NaN    NaN
# CV15846886           CLEVELAND EAST OF THE R        NaN    NaN
# CV15846970           CLEVELAND EAST OF THE R        NaN    NaN
# CV15847127           CLEVELAND WEST OF THE R        NaN    NaN
# CV15847556           CLEVELAND EAST OF THE R        NaN    NaN
# CV15847654           CLEVELAND WEST OF THE R        NaN    NaN
# CV15848045           CLEVELAND WEST OF THE R        NaN    NaN
# CV15848328           CLEVELAND WEST OF THE R        NaN    NaN
# CV93254070                               NaN        NaN  WITHD
# CV97341177                               NaN        NaN  WITHD
# CV97345013                               NaN        NaN  WITHD
# CV98354337                               NaN        NaN    NaN
# CV98354477                               NaN        NaN  WITHD
# CV98360458                               NaN        NaN    NaN
# CV98360731                               NaN        NaN  WITHD
# CV98361485                               NaN        NaN  WITHD
# CV98370749                               NaN        NaN  WITHD
# CV98371457                               NaN        NaN    NaN
# CV99373300                               NaN        NaN    NaN
# CV99373484                               NaN        NaN  WITHD
# CV99380061                               NaN        NaN  WITHD
# CV99383983                               NaN        NaN  WITHD
# CV99386629                               NaN        NaN    NaN
# CV99387728                               NaN        NaN  WITHD
# CV99390425                               NaN        NaN    NaN
# CV99397370                               NaN        NaN    NaN
# CV99398582                               NaN        NaN  WITHD
# CVH 24907            CLEVELAND EAST OF THE R        NaN    NaN
#
#                                              status ssold SHF   LATITUDE  \
# scaseno
# 05CV19450                                       NaN   Yes   1  41.480887
# 06CV027418                                      NaN   Yes   1  41.461490
# 07CVH13068                                      NaN   Yes   1  41.463530
# 08CVH06194                                      NaN   Yes   1  41.495223
# 163,708 PLURIES                                 NaN   NaN   1  41.535467
#                      LONGITUDE purchaser_count    REO
# scaseno
# 05CV19450           -81.733385               1  False
# 06CV027418          -81.636612               1  False
# 07CVH13068          -81.698954               1   True
# 08CVH06194          -81.648880               1  False
# 163,708 PLURIES     -81.596587               0  False
# 178,329 2ND PLURIES -81.555868               1  False
# 178,329 3RD PLURIES -81.555868               1  False
# 2007CVH18584        -81.747836             147   True
# 2008CVH30738        -81.628344               1  False
# 209,622 2ND PLURIES -81.613281               1   True
# 209,622 PLURIES     -81.613281               1   True
# 227,494 PLURIES     -81.704277               0  False
# 235,476 2ND PLURIES -81.594983               1   True
# 238,634 PLURIES     -81.578141               1  False
# 240,925 ALIAS       -81.582796               0  False
# 243,961 4TH PLURIES -81.597821               0  False
# 247,504             -81.778133               5   True
# 249,337 PLURIES     -81.583676               0  False
# 253,810 4TH PLURIES -81.588855               1  False
# 254,070             -81.746053               0  False
# 255,828 2ND PLURIES -81.555655               0  False
# 255,828 3RD PLURIES -81.555655               0  False
# 255,828 4TH PLURIES -81.555655               0  False
# 255,828 5TH PLURIES -81.555655               0  False
# 255,828 6TH PLURIES -81.555655               1  False
# 256,449 ALIAS       -81.627116               1  False
# 262,104 3RD PLURIES -81.572696               0  False
# 266,292 2ND PLURIES -81.761916               0  False
# 267,418 2ND PLURIES -81.557889               1   True
# 267,546 2ND PLURIES -81.613947              17  False
# ...                        ...             ...    ...
# CV15846273          -81.542225               0  False
# CV15846698          -81.745964               0  False
# CV15846757          -81.690902               6   True
# CV15846886          -81.588753               0  False
# CV15846970          -81.638045               0  False
# CV15847127          -81.744503               0  False
# CV15847556          -81.593688               0  False
# CV15847654          -81.767696               0  False
# CV15848045          -81.808508               0  False
# CV15848328          -81.780803               0  False
# CV93254070          -81.746053               0  False
# CV97341177          -81.720345               0  False
# CV97345013          -81.723794               0  False
# CV98354337          -81.575883             444   True
# CV98354477          -81.714571               0  False
# CV98360458          -81.562350             391   True
# CV98360731          -81.596878               0  False
# CV98361485          -81.552677             444   True
# CV98370749          -81.549188               0  False
# CV98371457          -81.632591               1  False
# CV99373300          -81.613821               8   True
# CV99373484          -81.570483               0  False
# CV99380061          -81.552323               0  False
# CV99383983          -81.606239               0  False
# CV99386629          -81.748904               1   True
# CV99387728          -81.602400               0  False
# CV99390425          -81.578369               1   True
# CV99397370          -81.574698             115   True
# CV99398582          -81.609334               0  False
# CVH 24907           -81.621056               1  False
#
# [36405 rows x 26 columns]

# %%
spas_sa = tci[tci.parcel.isin(test)][['SPA_NAME','vacant']].groupby('SPA_NAME').agg([sum,len])
spas_sa['percent'] = spas_sa.vacant['sum']*1.0/spas_sa.vacant['len']
print(spas_sa.sort_values('percent'))

# %%
for i in spas_sa.index:
    a = sa[sa.parcel.isin(test.intersection(tci[tci.SPA_NAME==i].parcel))]
    spas_sa.loc[spas_sa.index==i,'median_sa'] = a.sort_values('date')['date'].iloc[round(len(a)/2)]
#     print(i,a.sort_values('date')['date'].iloc[round(len(a)/2)])
#     print(np.median(sa[sa.parcel.isin(test.intersection(tci[tci.SPA_NAME==i].parcel))].date))

# %%
spas_sa

# %%
tci[tci.parcel.isin(set(fc.parcel))][['SPA_NAME','vacant']].groupby('SPA_NAME').agg([sum,len])

# %%
len(tci.loc[tci.vacant==1,'parcel'][tci.loc[tci.vacant==1,'parcel'].isin(set(sa.parcel))])

# %%
sum(tci['vacant']), len(tci)

# %%
sum(tci[tci.parcel.isin(sub)].vacant), len(tci[tci.parcel.isin(sub)].vacant)

# %%
last = df.groupby('parcel').last()
sub = set(last[last['type'] == 'sa'].index)

# %%
second_last = df.groupby('parcel').nth(-2)
sub2 = set(second_last[second_last['type']=='fc'].index)

# %%
len(sub.intersection(sub2)), len(sub), len(sub2)

# %%
fc_to_sa = sub.intersection(sub2)

# %%
sum(tci[tci.parcel.isin(fc_to_sa)].vacant), len(tci[tci.parcel.isin(fc_to_sa)].vacant)

# %%
df[df.parcel=='137-25-057']

# %%
a = second_last[second_last.index.isin(sub)]

# %%
pitt_vacant = set(second_last[second_last.index.isin(sub)].index)

# %%
sum(tci[tci.parcel.isin(set(a.index))].vacant), len(tci[tci.parcel.isin(set(a.index))].vacant)

# %%
sum(tci[(tci.parcel.isin(pitt_vacant))&(tci.parcel.isin(pitt))].vacant), len(tci[tci.parcel.isin(pitt_vacant)].vacant)

# %%
sum(tci.vacant)

# %%
1334.0/ 3892

# %%
temp = df[df.parcel.isin(pitt_vacant)].groupby('parcel').agg(lambda x: (x.date.iloc[-1]-x.date.iloc[-2]).days)

# %%
np.median(temp.date)

# %%
sns.distplot(temp.date);

# %%
pv = pd.read_csv(path+'/data/clean_data/postal_vacancy.csv', parse_dates=3, index_col=0)
pv.date = pv.date.apply(lambda x: dt.datetime(int(x[0:4]),int(x[5:7]),int(x[8:10])))
pv = pv.sort_values('date',ascending=False)
pv = pv.loc[pv.apply(lambda x: x.date < dates[x.PARCEL], axis=1)]

# %%
pv = pv[pv.vindall=='Y']
pv_copy = pv.copy().groupby('PARCEL').count().reset_index()

pv_copy['pv_count'] = pv_copy.apply(lambda x: \
        len(pv[(pv.PARCEL == x.PARCEL) & (pv.date > dates[x.PARCEL]-pd.DateOffset(years=2))]), axis=1)

# %%
pv2 = pv.groupby('PARCEL').last()

# %%
tci[tci.parcel.isin(pv2[pv2.vindall=='Y'].index)].groupby('vacant').count()

# %%
sns.distplot(df2[df2.vacant==1].date,bins=np.linspace(0,30,30));
sns.distplot(df2[df2.vacant==0].date,bins=np.linspace(0,30,30));

# %%
df2 = pd.merge(df.groupby('parcel').last(), tci[['vacant','ppn']], how='left',left_index=True, right_on='ppn')

# %%
df2[['type','vacant']].groupby('type').agg([sum,len])

# %%
d = df2[df2['type']=='fc']
d['year'] = d.date.apply(lambda x: x.year)

# %%
d[['year','vacant']].groupby('year').agg([sum,len])

# %%
plt.plot(fc.set_index('date').groupby(['type']).resample('m', 'count'))

# %%
t = tci[tci.ppn.isin(fc[fc.date > dt.datetime(2015,3,1)].parcel)].vacant

# %%
sum(t),len(t)

# %%
fc['year'] = fc['date']
