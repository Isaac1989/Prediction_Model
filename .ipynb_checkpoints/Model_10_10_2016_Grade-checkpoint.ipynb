# %% [markdown]
# ### Loading necessary packages or libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os 
from sklearn.cross_validation import cross_val_score
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn import metrics
from sklearn.preprocessing import binarize
from sklearn.grid_search import GridSearchCV, RandomizedSearchCV

# A sound object
def sound():
    os.system('Z:/largetransfer/luc/carter/Isaac/Sosumi.aiff')

# %matplotlib inline
sns.set_context('notebook')

wpath = 'Z:/largetransfer/luc/carter' #working from linux

lpath= "smb://WORKGROUP;ixo26@poprocks/dropbox/largetransfer/luc/carter" # working from linux
# Out:
# C:\Users\Aisik\Anaconda3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Users\Aisik\Anaconda3\lib\site-packages\sklearn\grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %% [markdown]
# #### Loading main data

# %%
data=pd.read_csv(wpath+'/data/model_data/tci_final1_10_10_2016.csv')
data.drop('Unnamed: 0',axis=1,inplace=True)

# %% [markdown]
# ### loading complementary data
# This data set is only  loaded in to collect specific data to be merged to the main data

# %%
data1=pd.read_csv('Z:/largetransfer/luc/carter/data/clean_data/tci_1_0.csv',parse_dates=[1])
# Out:
# C:\Users\Aisik\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# #### Function to parse date data

# %%
def parsePin(x):
    x=str(x)
    return x[:3]+'-'+x[3:5]+'-'+x[5:]
data1['PIN']=data1.PIN.apply(parsePin)

# %%
#subsetting data via nluc variable + attaching 'Survey grade' variable
ndata=pd.merge(data,data1[['PIN','Survey Grade']],left_on ='parcel', right_on='PIN',how ='left')
ndata['Survey Grade'].fillna('No Grade', inplace=True)
ndata=ndata.loc[(ndata.nluc==5100.0) | (ndata.nluc==5200.0) | (ndata.nluc==5300.0),]

# %%
##subsetting residential data via plcass variable
ndata=ndata.ix[ndata.pclass=='Residential',]
ndata.drop('pclass',inplace=True,axis=1)
ndata.rename(columns={'Survey Grade':'survey_grade'})
# Out:
#             parcel  vacant  rnumstor  propsize  totusabl    tmktval  \
# 0       001-01-001       0       1.0     32768    4149.0   445500.0
# 1       001-01-003       0       1.5     81536   15828.0  1159600.0
# 2       001-01-004       0       1.5     13832    2537.0   266300.0
# 3       001-01-005       0       1.5     10500    1578.0   171700.0
# 4       001-01-006       0       2.0     16500    3650.0   296200.0
# 5       001-01-007       0       2.0     12000    3300.0   324900.0
# 6       001-01-008       0       1.5     12000    2160.0   350500.0
# 7       001-01-009       0       2.0     11250    3590.0   365000.0
# 8       001-01-010       0       3.0     11250    2576.0   274900.0
# 9       001-01-011       0       1.5     11250    1652.0   179200.0
# 10      001-01-012       0       2.0      9750    3125.0   308300.0
# 11      001-01-013       0       1.5     11552    2498.0   266900.0
# 12      001-01-014       0       1.0     10950    1669.0   186500.0
# 13      001-01-015       0       2.0     19501    2528.0   237600.0
# 14      001-01-016       0       1.0     20538    2165.0   208400.0
# 15      001-01-017       0       1.0     10660    2001.0   209600.0
# 16      001-01-018       0       1.0     16030    1952.0   244600.0
# 17      001-01-020       0       1.5     12300    1864.0   194700.0
# 18      001-01-021       0       1.0     26082    1963.0   190700.0
# 19      001-01-023       0       2.0     12800    2666.0   185800.0
# 20      001-01-024       0       2.0     12800    3288.0   127500.0
# 21      001-01-025       0       2.0     10400    1482.0   150800.0
# 22      001-01-026       0       2.0     10400    1854.0   190700.0
# 23      001-01-027       0       1.0     11840    1975.0   228000.0
# 24      001-01-028       0       1.0     11664    1657.0   185600.0
# 25      001-01-029       0       1.0     13940    1750.0   202100.0
# 26      001-01-030       0       1.0     12300    1320.0   153000.0
# 27      001-01-031       0       1.0     12000    1648.0   141100.0
# 28      001-01-032       0       1.0     12000    2406.0   206400.0
# 29      001-01-033       0       1.0     26806    2785.0   370200.0
# ...            ...     ...       ...       ...       ...        ...
# 112934  433-24-023       0       2.0     17608    1265.0   102600.0
# 112935  433-24-060       0       1.5      5680     728.0    79000.0
# 112936  433-24-061       0       1.5      4880    1131.0    82600.0
# 112937  433-24-062       0       1.0      7320    1134.0    87400.0
# 112938  433-24-063       0       1.0      7320     768.0    85000.0
# 112939  433-24-102       0       2.0      6710    2160.0    93700.0
# 112940  433-24-104       0       1.5      4270    1152.0    84300.0
# 112941  433-24-105       0       1.5      4270    1152.0    90300.0
# 112942  531-01-001       0       1.5     22140    1116.0    89400.0
# 112943  546-19-069       0       1.5     39639    1176.0    69400.0
# 112944  631-14-001       0       1.5     14374    1716.0   109800.0
# 112945  631-14-038       0       2.0      4680    1674.0    85000.0
# 112946  631-14-039       0       1.5      4680    1540.0    73300.0
# 112947  631-14-040       0       1.5      7371    1442.0    81400.0
# 112948  649-01-075       0       2.0     16800    2042.0   118200.0
# 112949  672-02-125       0       2.0      5418    2716.0    54000.0
# 112950  672-13-030       0       2.0      4446    1486.0    24400.0
# 112951  672-13-031       0       2.0      3762    1444.0    22800.0
# 112952  672-14-130       0       2.5      3535    2487.0    38600.0
# 112953  672-14-131       0       2.0      3535    1736.0    41000.0
# 112955  672-14-133       0       2.0      3325    1308.0    36200.0
# 112956  673-16-003       0       2.0      5560    1232.0    56800.0
# 112957  673-16-004       0       2.0      5760    1248.0    53100.0
# 112958  673-16-025       0       2.0      4800    1220.0    46100.0
# 112959  682-04-106       0       2.0     27000    3132.0   172400.0
# 112960  731-11-046       0       2.0      7800    2009.0   146400.0
# 112961  735-14-016       0       2.5      7680    3510.0   144300.0
# 112962  735-15-074       0       2.0      6300    1764.0    88600.0
# 112963  735-15-075       0       2.0      6300    1609.0   103700.0
# 112964  735-20-001       1       1.5      5207    1008.0    83800.0
#
#         condition_value14  ownerocc_value  totbldgs  yrbuilt_filtered  \
# 0                     5.0               1         1              1951
# 1                     8.0               1         1              1962
# 2                     6.0               1         1              1957
# 3                     6.0               1         1              1953
# 4                     8.0               1         1              1928
# 5                     7.0               1         1              1927
# 6                     7.0               1         1              1961
# 7                     6.0               1         1              1928
# 8                     6.0               1         1              1928
# 9                     7.0               1         1              1950
# 10                    7.0               0         1              1927
# 11                    7.0               1         1              1949
# 12                    6.0               0         1              1958
# 13                    6.0               1         1              1890
# 14                    5.0               1         1              1959
# 15                    6.0               1         1              1955
# 16                    6.0               1         1              1955
# 17                    7.0               1         1              1952
# 18                    6.0               1         1              1954
# 19                    6.0               1         1              1964
# 20                    8.0               1         1              1924
# 21                    5.0               1         1              1953
# 22                    6.0               1         1              1929
# 23                    6.0               1         1              1956
# 24                    5.0               1         1              1956
# 25                    6.0               1         1              1956
# 26                    6.0               1         1              1956
# 27                    5.0               1         1              1956
# 28                    6.0               1         1              1956
# 29                    6.0               1         1              1958
# ...                   ...             ...       ...               ...
# 112934                5.0               1         1              1949
# 112935                5.0               1         1              1950
# 112936                5.0               1         1              1950
# 112937                5.0               0         1              1949
# 112938                5.0               1         1              1949
# 112939                5.0               1         1              1949
# 112940                5.0               0         1              1925
# 112941                5.0               1         1              1951
# 112942                4.0               1         1              1953
# 112943                5.0               1         1              1909
# 112944                5.0               1         1              1954
# 112945                6.0               1         1              1927
# 112946                4.0               0         1              1948
# 112947                6.0               1         1              1948
# 112948                5.0               1         1              1964
# 112949                5.0               1         1              1923
# 112950                3.0               1         1              1894
# 112951                3.0               1         1              1894
# 112952                3.0               1         1              1906
# 112953                4.0               1         1              1903
# 112955                3.0               0         1              1911
# 112956                5.0               1         1              1941
# 112957                4.0               1         1              1938
# 112958                5.0               0         1              1941
# 112959                5.0               1         1              1955
# 112960                5.0               1         1              1924
# 112961                5.0               1         1              1929
# 112962                5.0               0         1              1924
# 112963                5.0               1         1              1925
# 112964                4.0               1         1              1941
#
#             ...       t_days  t_shf_deed     t_num    al_num  al_days  \
# 0           ...         3508        3543  0.000000  0.000000     3508
# 1           ...         3508        3543  0.104048  0.000000     3508
# 2           ...         3508        3543  0.104048  0.104048     3077
# 3           ...         3508        3543  0.208096  0.104048      187
# 4           ...         3508        3543  0.000000  0.000000     3508
# 5           ...         3508        3543  0.104048  0.000000     3508
# 6           ...         3508        3543  0.000000  0.000000     3508
# 7           ...         3508        3543  0.416192  0.208096      420
# 8           ...         3508        3543  0.104048  0.000000     3508
# 9           ...         3508        3543  0.104048  0.104048     1335
# 10          ...         3508        3543  0.000000  0.000000     3508
# 11          ...         3508        3543  0.000000  0.000000     3508
# 12          ...         3508        3543  0.520239  0.104048      691
# 13          ...         3508        3543  0.000000  0.000000     3508
# 14          ...         3508        3543  0.208096  0.000000     3508
# 15          ...         3508        3543  0.000000  0.000000     3508
# 16          ...         3508        3543  0.000000  0.000000     3508
# 17          ...         3508        3543  0.104048  0.000000     3508
# 18          ...         3508        3543  0.000000  0.000000     3508
# 19          ...         3508        3543  0.000000  0.000000     3508
# 20          ...         3508        3543  0.312144  0.104048     2155
# 21          ...         3508        3543  0.000000  0.000000     3508
# 22          ...         3508        3543  0.104048  0.104048     3302
# 23          ...         3508        3543  0.104048  0.104048     1508
# 24          ...         3508        3543  0.104048  0.104048     1928
# 25          ...         3508        3543  0.000000  0.000000     3508
# 26          ...         3508        3543  0.000000  0.000000     3508
# 27          ...         3508        3543  0.312144  0.312144      290
# 28          ...         3508        3543  0.104048  0.104048      224
# 29          ...         3508        3543  0.104048  0.000000     3508
# ...         ...          ...         ...       ...       ...      ...
# 112934      ...         3484        3543  0.209529  0.209529      121
# 112935      ...         3484        3543  0.000000  0.000000     3484
# 112936      ...         3484        3543  0.104765  0.000000     3484
# 112937      ...         3484        3543  0.314294  0.209529     2201
# 112938      ...         3484        2102  0.314294  0.209529     2102
# 112939      ...         3484        3543  0.000000  0.000000     3484
# 112940      ...         3484        3543  0.000000  0.000000     3484
# 112941      ...         3484        3543  0.000000  0.000000     3484
# 112942      ...         3484        3543  0.000000  0.000000     3484
# 112943      ...         3532        3508  0.206682  0.103341     3163
# 112944      ...         3446        3543  0.000000  0.000000     3446
# 112945      ...         3446        3543  0.105920  0.105920      280
# 112946      ...         3446        3543  0.211840  0.105920     2412
# 112947      ...         3446        3543  0.105920  0.105920     3435
# 112948      ...         3449        3543  0.000000  0.000000     3449
# 112949      ...         3453        3543  0.000000  0.000000     3453
# 112950      ...         3462        3543  0.000000  0.000000     3462
# 112951      ...         3462        3543  0.000000  0.000000     3462
# 112952      ...         3462        3543  0.000000  0.000000     3462
# 112953      ...         3462        3543  0.000000  0.000000     3462
# 112955      ...         3462        3543  0.000000  0.000000     3462
# 112956      ...         3449        3543  0.000000  0.000000     3449
# 112957      ...         3449         490  0.317483  0.105828      375
# 112958      ...         3449        3543  0.423311  0.211656     1904
# 112959      ...         3449        3543  0.000000  0.000000     3449
# 112960      ...         3469        2324  0.210435  0.105218     2135
# 112961      ...         3480        3543  0.000000  0.000000     3480
# 112962      ...         3480        3162  0.209770  0.104885     2940
# 112963      ...         3480        3543  0.104885  0.000000     3480
# 112964      ...         3564          40  0.102413  0.000000     3564
#
#         price_per_sqft    nluc   NAME10         PIN  survey_grade
# 0           107.375271  5100.0  1011.02  001-01-001             A
# 1            73.262573  5100.0  1011.02  001-01-003             A
# 2           104.966496  5100.0  1011.02  001-01-004             A
# 3           108.808619  5100.0  1011.02  001-01-005             B
# 4            81.150685  5100.0  1011.02  001-01-006             A
# 5            98.454545  5100.0  1011.02  001-01-007             A
# 6           162.268519  5100.0  1011.02  001-01-008             A
# 7           101.671309  5100.0  1011.02  001-01-009             A
# 8           106.715839  5100.0  1011.02  001-01-010             A
# 9           108.474576  5100.0  1011.02  001-01-011             A
# 10           98.656000  5100.0  1011.02  001-01-012             B
# 11          106.845476  5100.0  1011.02  001-01-013             A
# 12          111.743559  5100.0  1011.02  001-01-014             A
# 13           93.987342  5200.0  1011.02  001-01-015             A
# 14           96.258661  5100.0  1011.02  001-01-016             A
# 15          104.747626  5100.0  1011.02  001-01-017             A
# 16          125.307377  5100.0  1011.02  001-01-018             A
# 17          104.452790  5100.0  1011.02  001-01-020             A
# 18           97.147224  5100.0  1011.02  001-01-021             B
# 19           69.692423  5100.0  1011.02  001-01-023             A
# 20           38.777372  5100.0  1011.02  001-01-024             A
# 21          101.754386  5100.0  1011.02  001-01-025             A
# 22          102.858684  5100.0  1011.02  001-01-026             A
# 23          115.443038  5100.0  1011.02  001-01-027             A
# 24          112.009656  5100.0  1011.02  001-01-028             A
# 25          115.485714  5100.0  1011.02  001-01-029             A
# 26          115.909091  5100.0  1011.02  001-01-030             A
# 27           85.618932  5100.0  1011.02  001-01-031             A
# 28           85.785536  5100.0  1011.02  001-01-032             A
# 29          132.926391  5100.0  1011.02  001-01-033             A
# ...                ...     ...      ...         ...           ...
# 112934       81.106719  5100.0  1065.00  433-24-023             A
# 112935      108.516484  5100.0  1065.00  433-24-060             A
# 112936       73.032714  5100.0  1065.00  433-24-061             A
# 112937       77.072310  5100.0  1065.00  433-24-062             A
# 112938      110.677083  5100.0  1065.00  433-24-063             A
# 112939       43.379630  5100.0  1065.00  433-24-102             A
# 112940       73.177083  5100.0  1065.00  433-24-104             A
# 112941       78.385417  5100.0  1065.00  433-24-105             A
# 112942       80.107527  5100.0  1070.00  531-01-001             B
# 112943       59.013605  5100.0  1222.00  546-19-069             A
# 112944       63.986014  5100.0  1171.02  631-14-001             A
# 112945       50.776583  5100.0  1171.02  631-14-038             A
# 112946       47.597403  5100.0  1171.02  631-14-039             B
# 112947       56.449376  5100.0  1171.02  631-14-040             A
# 112948       57.884427  5100.0  1261.00  649-01-075             A
# 112949       19.882180  5200.0  1166.00  672-02-125             C
# 112950       16.419919  5100.0  1188.00  672-13-030             B
# 112951       15.789474  5100.0  1188.00  672-13-031             B
# 112952       15.520708  5200.0  1188.00  672-14-130             C
# 112953       23.617512  5100.0  1188.00  672-14-131             B
# 112955       27.675841  5100.0  1188.00  672-14-133             B
# 112956       46.103896  5100.0  1261.00  673-16-003             A
# 112957       42.548077  5100.0  1261.00  673-16-004             B
# 112958       37.786885  5100.0  1179.00  673-16-025             B
# 112959       55.044700  5100.0  1261.00  682-04-106             A
# 112960       72.872076  5100.0  1197.01  731-11-046             B
# 112961       41.111111  5200.0  1199.00  735-14-016      No Grade
# 112962       50.226757  5100.0  1199.00  735-15-074             B
# 112963       64.449969  5100.0  1199.00  735-15-075             A
# 112964       83.134921  5100.0  1217.00  735-20-001             B
#
# [110629 rows x 58 columns]

# %%
condition_value = {0.0:'Unsound', 1.:'Sound', 2.:'Very poor', 3.:'Poor', 4.:'Fair', 5.:'Average', \
                   6.:'Good', 7.:'Very good', 8.:'Excellent'}
ndata['conditions']=ndata.condition_value14.map(condition_value)
ndata.conditions.fillna('Average',inplace=True)
ndata.drop('condition_value14',inplace=True, axis=1)
ndata.conditions.str.lower()
# Out:
# 0           average
# 1         excellent
# 2              good
# 3              good
# 4         excellent
# 5         very good
# 6         very good
# 7              good
# 8              good
# 9         very good
# 10        very good
# 11        very good
# 12             good
# 13             good
# 14          average
# 15             good
# 16             good
# 17        very good
# 18             good
# 19             good
# 20        excellent
# 21          average
# 22             good
# 23             good
# 24          average
# 25             good
# 26             good
# 27          average
# 28             good
# 29             good
#             ...
# 112934      average
# 112935      average
# 112936      average
# 112937      average
# 112938      average
# 112939      average
# 112940      average
# 112941      average
# 112942         fair
# 112943      average
# 112944      average
# 112945         good
# 112946         fair
# 112947         good
# 112948      average
# 112949      average
# 112950         poor
# 112951         poor
# 112952         poor
# 112953         fair
# 112955         poor
# 112956      average
# 112957         fair
# 112958      average
# 112959      average
# 112960      average
# 112961      average
# 112962      average
# 112963      average
# 112964         fair
# Name: conditions, dtype: object

# %%
Good=['very good','excellent','good']
average=['fair','average','sound value']
poor=['unsound','poor','very poor']

def parseC(x):
    if x.lower() in Good:
        return 'good'
    elif x.lower() in average:
        return 'average'
    else: return 'poor'
ndata['condition']=ndata.conditions.apply(parseC)
ndata.drop('conditions',axis=1,inplace=True)
ndata.drop('PIN', axis=1, inplace=True)

# %%
ndata.reset_index(inplace=True)
cond_dummy= pd.get_dummies(ndata.condition) 
cond_dummy['parcel']=ndata.parcel
ndata= pd.merge(ndata, cond_dummy,left_on='parcel', right_on= 'parcel',how='left')
ndata.set_index('parcel', inplace=True)
ndata.drop('index', axis=1, inplace = True)

# %%
#Removing certain features from the data set
t = list(ndata.columns)
for i in ['vacant_block'\
          'part_one_crimes','part_two_crimes',
          'white','asian','other','hispanic','young','middle','old','nluc','vacant',\
        ]:
    if i in t:
        t.remove(i)
    
features = t

# %%
X_train,X_test,y_train,y_test=train_test_split(ndata[features],ndata["vacant"],test_size=0.2,random_state=7)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (88503, 49)
# (22126, 49)
# (88503,)
# (22126,)

# %%
X_train1=X_train.drop(['Survey Grade', 'condition','NAME10'],axis=1)
X_test1=X_testr=X_test.drop(['Survey Grade', 'condition','NAME10'],axis=1)

# %% [markdown]
# #  Building models

# %% [markdown]
# ### Fitting Random Forest

# %%
from scipy.stats import randint as sp_randint
from sklearn.externals import joblib
from time import time

n_trees=list(range(40,81))
n_features=list(range(20,31))

# param_grid=dict(n_estimators=n_trees,max_features=n_features)
start_time=time()

param_dist=dict(n_estimators=sp_randint(50,81),max_features=sp_randint(20,31))
    
rfc=RandomForestClassifier(class_weight={0:1,1:10},random_state=6)
# grid_rfc=GridSearchCV(rfc,param_grid,cv=10,scoring="accuracy") 
rand_rfc=RandomizedSearchCV(rfc, param_dist,cv=10,scoring="accuracy",n_iter=10)

# grid_rfc.fit(X_train,y_train)
rand_rfc.fit(X_train1,y_train)

joblib.dump(rand_rfc, "Z:/largetransfer/luc/carter/Isaac/model_files/rand_rfc1.pkl")

end_time=time()-start_time
sound()

# %% [markdown]
# ### Fitting Gradient Boosting

# %%
from scipy.stats import randint as sp_randint
from time import time
from itertools import islice,count
from sklearn.externals import joblib

start=time()

param_dist=dict(n_estimators= sp_randint(200,250),\
                max_features= sp_randint(20,30),\
                max_depth= sp_randint(2,10),\
               learning_rate =list(islice(count(0.01,0.01),0,10)))
         
gbm=GradientBoostingClassifier(random_state=10)

rand_gbm=RandomizedSearchCV(gbm,param_dist,cv=10,scoring='accuracy',n_iter=5)

rand_gbm.fit(X_train1,y_train)

joblib.dump(rand_gbm,"Z:/largetransfer/luc/carter/Isaac/model_files/rand_gbm1.pkl")

end_time=time()-start
sound()

# %% [markdown]
# ### Fitting logistic regression

# %%
from sklearn.preprocessing import StandardScaler
from time import time
from sklearn.externals import joblib
start_time=time()
# Scaling features

X_train1=StandardScaler().fit_transform(X_train1)
#X_test1=StandardScaler().fit_transform(X_test1)

# Parameter options using the l1 penalty
grid_param1={'penalty':['l2'],\
           'solver':['newton-cg'],\
           'C':[ 0.001,0.01, 0.1, 1, 10,100,1000]}

log_reg1=LogisticRegression(tol=0.0001, max_iter=300,class_weight={0:1,1:10})

# Creating gridsearch obj using the above setings
grid_reg1=GridSearchCV(log_reg1,grid_param1,cv=10,scoring='accuracy',error_score=0)

grid_reg1.fit(X_train1,y_train)

joblib.dump(grid_reg1,'Z:/largetransfer/luc/carter/Isaac/model_files/logistic_reg.pkl')

total_time=time()-start_time

sound()

# %% [markdown]
# ## Making predictions

# %%
from sklearn.externals import joblib
logistic=joblib.load('Z:/largetransfer/luc/carter/Isaac/model_files/logistic_reg.pkl')
gradientB=joblib.load('Z:/largetransfer/luc/carter/Isaac/model_files/rand_gbm1.pkl')
RandomF=joblib.load("Z:/largetransfer/luc/carter/Isaac/model_files/rand_rfc1.pkl")

# %% [markdown]
# ### Logistic

# %%
#Best model after the Randomized search
logistic.best_estimator_
# Out:
# LogisticRegression(C=0.001, class_weight={0: 1, 1: 10}, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=300,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='newton-cg', tol=0.0001, verbose=0, warm_start=False)

# %%
#Checking the parameters used for the model selection
logistic.best_params_
# Out:
# {'C': 0.001, 'penalty': 'l2', 'solver': 'newton-cg'}

# %%
#predicted values
from sklearn.preprocessing import StandardScaler
X_testlg=StandardScaler().fit_transform(X_testr)
predicted=logistic.predict(X_testlg)

# %%
#Measuring model accuracy
metrics.accuracy_score(y_test,predicted)
# Out:
# 0.87060471843080534

# %%
metrics.confusion_matrix(y_test,predicted)
# Out:
# array([[17791,  2439],
#        [  424,  1472]])

# %%
pd.crosstab(y_test,predicted, margins=True,colnames=['predicted'],rownames=['Actual'])
# Out:
# predicted      0     1    All
# Actual
# 0          17791  2439  20230
# 1            424  1472   1896
# All        18215  3911  22126

# %%
# Visualizing the distribution of the  predicted probabilities
# sns.set_style('white')

predprob=logistic.predict_proba(X_testlg)[:,1]

def distprob(predprob,threshold,model='',adjusted=False):
    """Utility for plotting the distribution probability"""
    
    sns.distplot(predprob,kde=False)
    plt.axvline(threshold,color='DarkBlue', alpha=0.5)
    plt.xlabel('predicted probabilities')
    ax=plt.gca()
    ax.annotate('Decision boundary', xy=(threshold,7500), xytext=(threshold+0.2,8000),
                arrowprops=dict(facecolor='black', shrink=0.08),
                )
    if adjusted:
        plt.title(model +' with adjusted threshold:%.2f'%threshold)
    else:
        plt.title(model)


    
distprob(predprob,0.5,'logistic regression')

# %%
dsource=pd.read_excel('Z:/largetransfer/luc/carter/data/model_data/model_variables_and_sources.xlsx')
dsource=dsource.rename(columns={'Variable names':'variables'})
dsource['source']=dsource.source.str.lower()
dsource['variables']=dsource.variables.str.lower()
dsource
# Out:
#                   variables variable type  \
# 0                    vacant       derived
# 1                    al_num       derived
# 2                   al_days       derived
# 3   days_since_ovv_board_up       derived
# 4            days_since_ovv       derived
# 5              vacant_block      original
# 6               median_rent      original
# 7           property_crimes      original
# 8                burglaries      original
# 9           part_one_crimes      original
# 10          part_two_crimes      original
# 11               bachelors+      original
# 12             poverty_rate      original
# 13         median_hh_income      original
# 14                    white      original
# 15                    black      original
# 16                    asian      original
# 17                 hispanic      original
# 18                    young      original
# 19                   middle      original
# 20                      old      original
# 21                   fc_1yr       derived
# 22                   fc_2yr       derived
# 23                active_fc       derived
# 24              lb_acquired       derived
# 25                lb_tax_fc       derived
# 26                 propsize      original
# 27           condition13&14      original
# 28                 totusabl      original
# 29                  tmktval      original
# 30                 totbldgs      original
# 31           ownerocc_value       derived
# 32           style_filtered       derived
# 33         yrbuilt_filtered       derived
# 34                   pclass      original
# 35                      zip      original
# 36                 pv_count       derived
# 37                    occup      original
# 38                 rnumstor      original
# 39                    cqual      original
# 40   total_net_delq_balance      original
# 41        tax_assessed_land      original
# 42          tax_market_land      original
# 43      grand_total_balance      original
# 44         grand_total_paid      original
# 45         delq_total_ratio       derived
# 46             paid_percent       derived
# 47   grand_total_balance_14      original
# 48           price_per_sqft      original
# 49                   t_days       derived
# 50               t_shf_deed       derived
# 51                    t_num       derived
# 52              v_total_1yr       derived
# 53              v-total_2yr       derived
#
#                                           Description           source
# 0            "Vacant structure" as 1 and 0 other wise  tci survey data
# 1                 Total number of armsales since 2006   armlength sale
# 2   Total number of days since last armsales to pr...   armlength sale
# 3   number of days since OVV was boarded up  since...       complaints
# 4   Number of days since parcel has been in ovv si...       complaints
# 5   Vacant housing units, percent, 2012 5-yr est (...      demograhics
# 6   Median gross rent, number, 2012 5-yr est (ACS ...      demograhics
# 7   Property crimes, rate per 100,000 population, ...      demograhics
# 8   Burglaries, rate per 100,000 population, 2014 ...      demograhics
# 9   Part I crimes, rate per 100,000 population, 20...      demograhics
# 10  Part II crimes, rate per 100,000 population, 2...      demograhics
# 11  Persons with bachelors degree or more, percent...      demograhics
# 12      Poverty rate, 2012 5-yr est (ACS 2012 5-year)      demograhics
# 13  Median household income, 2012 5-yr est (ACS 20...      demograhics
# 14    White, percent, 2012 5-yr est (ACS 2012 5-year)      demograhics
# 15    Black, percent, 2012 5-yr est (ACS 2012 5-year)      demograhics
# 16  Asian/Pac Islander, percent, 2012 5-yr est (AC...      demograhics
# 17  Hispanic, percent, 2012 5-yr est (ACS 2012 5-y...      demograhics
# 18  Population aged 0-17, percent, 2012 5-yr est (...      demograhics
# 19  Population aged 18-64, percent, 2012 5-yr est ...      demograhics
# 20  Population aged 65+, percent, 2012 5-yr est (A...      demograhics
# 21  Total count of forclosure filing a year before...      foreclosure
# 22  Total count of forclosure filing 2 years befor...      foreclosure
# 23  Sets active foreclosure till date to 1 and 0 o...      foreclosure
# 24      Encodes acquired parcels as 1 and 0 otherwise        land bank
# 25       encodes tax foreclosure as 1 and 0 otherwise        land bank
# 26                         square footage of property    main_property
# 27      condition of parcels as at year 2013 and 2014    main_property
# 28                                  total usable area    main_property
# 29                     total market value in dollars     main_property
# 30                      number of buildings on parcel    main_property
# 31  Encodes "ownerocc" variable as 1 for yes and 0...    main_property
# 32   Parcel style: Bungalow','CAP','Colonial','Ranch'    main_property
# 33  Integer version of the original "yrbuilt" vari...    main_property
# 34                                     property class    main_property
# 35                                 zip code of parcel    main_property
# 36                counts of postal vacancy since 2006   postal_vacancy
# 37                   Property type [(1,2,3,4)family ]      residential
# 38                                 Number of stories?      residential
# 39                               condition of parcels      residential
# 40               Certified total deliquent taxes owed              tax
# 41                       Total assessed value of land              tax
# 42                         Total market value of land              tax
# 43                                   Total taxes owed              tax
# 44                                   Total taxes paid              tax
# 45        Ratio of tax deliquency to grand total owed              tax
# 46            Ratio of total paid to grand total owed              tax
# 47                                                NaN              tax
# 48    Total market values per square feet of a parcel    main_property
# 49                Total number of days since transfer         transfer
# 50      Total number of days sinc sheriff's deep type         transfer
# 51               Total number of transfers since 2006         transfer
# 52  number of violations filed with in 1 yr period...       violations
# 53  number of violations filed with in 2 yr period...       violations

# %%
#Coefficients of the model
coef=logistic.best_estimator_.coef_.T[:46].ravel()
# coef=logistic.best_estimator_.coef_.T.ravel()
var=X_train1.columns.values[:46]
df=pd.DataFrame(dict(list(zip(['variables','coef'],[var,coef]))))
df['variables']=df.variables.str.lower()
df=pd.merge(df,dsource[['variables','source']],on='variables',how='left')
df.loc[df.variables=='bachelors.','source']='demographics'
df.loc[df.variables=='v_total_2yr','source']='violations'
df.loc[df.variables=='c_ovv_board_num','source']='complaints'
df.loc[df.variables== 'c_ovv_num','source']='complaints'
df.loc[df.variables=='fc_days','source']='foreclosure'
# df.iloc[df.shape[0]-4:,'source']='condition'
df=df.fillna('condition',axis=1)
df['source']=df.source.str.replace('_',' ')
df['source']=df.source.str.capitalize()
    
sources=set(df.source)
for s in sources:
    l=df.ix[df.source==s,].shape[0]
    idx=df.ix[df.source==s,].index.values
    if l != 1:
        for i in range(l):
            df.loc[df.index==idx[i],'source']= s + str(i)

# %%
# Tuning the prediction probabilities and setting roc_curve
adjusted_prediction=np.where(predprob>0.9,1,0)

# %%
pd.crosstab(y_test,adjusted_prediction,colnames=['predicted'],rownames=['Actual'])
# Out:
# predicted      0    1
# Actual
# 0          19907  323
# 1            928  968

# %%
#adjusting the decision line to 0.8
distprob(predprob,0.8,adjusted=True, model='Logistic Regression')

# %% [markdown]
# ### Random Forest

# %%
features=df.source

# %%
RandomF.best_estimator_
# Out:
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 10},
#             criterion='gini', max_depth=None, max_features=21,
#             max_leaf_nodes=None, min_impurity_split=1e-07,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=58, n_jobs=1,
#             oob_score=False, random_state=6, verbose=0, warm_start=False)

# %%
important_features=RandomF.best_estimator_.feature_importances_
feature_map=dict(zip(['features','values'],[features,important_features]))
pd.DataFrame(feature_map).head()
# Out:
#          features    values
# 0     Residential  0.005235
# 1  Main property0  0.026261
# 2  Main property1  0.028392
# 3  Main property2  0.029341
# 4  Main property3  0.004776

# %%
#variable importance plotting utility


def important_feature_plot(variables,values,model=''):
    # Plot feature importance
    sns.set_context('talk')

    # make importances relative to max importance
    features1=np.array(variables)
    feature_importance = 100.0 * (values / values.max())
    sorted_idx = np.argsort(feature_importance)
    pos = np.arange(sorted_idx.shape[0]) + .5
#     plt.subplot(1, 2, 2)
    plt.barh(pos, feature_importance[sorted_idx], align='center')
    plt.yticks(pos,features1[sorted_idx])
    plt.xlabel('Relative Importance')
    plt.title('Variable Importance: '+ model)
    plt.show()
    
# feature_lab=['Residential 1','Main property 1','Main property 1','Main property 2','Main property 3','Main property 4'\
#             ,'Main property 5','Demographics','Land & Banks 1','Land & Banks 2','Tax 1','Tax 2','Tax 3','Tax 4','Tax 5','Tax 6'\
#             ,'Tax 7','Tax 8','Postal vacancy','Violations 1','Violations 2','Complaints 1','Complaints 2','Complaints 3','Complaints 4',\
#             'Foreclosure 1','Foreclosure 2','Foreclosure 3','Foreclosure 4','Transfer 1','Transfer 2','Transfer 3','Armslength 1','Armslength 2',\
#             'Tax 9']

important_feature_plot(features,important_features,'Random forest')

# %%
#Making a prediction
predicted_rf=RandomF.predict(X_test1)
pd.crosstab(y_test,predicted_rf,colnames=['predicted'],rownames=['Actual'])
# Out:
# predicted      0    1
# Actual
# 0          20009  221
# 1           1019  877

# %%
print('Calculated score: %.5f \n RandomizedScore: %.5f'%(metrics.accuracy_score(y_test,predicted_rf),RandomF.best_score_))
# Out:
# Calculated score: 0.94396
#  RandomizedScore: 0.94134

# %%
#prediction probability
# prob_rf=RandomF.predict_proba(X_test1)[:,1]
# plt.subplot(211)
# distprob(prob_rf,0.5,model='Random Forest')
# plt.subplot(212)
# distprob(prob_rf,0.4,model='Random Forest', adjusted=True)

# %%
#prediction probability
prob_rf=RandomF.predict_proba(X_test1)[:,1]

distprob(prob_rf,0.5,model='Random Forest')

# %%
#prediction probability
prob_rf=RandomF.predict_proba(X_test1)[:,1]
distprob(prob_rf,0.4,model='Random Forest', adjusted=True)

# %%
#Adjusting the thresholds and setting the roc curves
newpred_rf=np.where(prob_rf>0.4,1,0)

pd.crosstab(y_test,newpred_rf,colnames=['predicted'],rownames=['Actual'])
# Out:
# predicted      0    1
# Actual
# 0          19866  364
# 1            904  992

# %% [markdown]
# ### Gradient Boosting

# %%
#checking the best estimator obtained from the Randomized grid parameter search
gradientB.best_estimator_
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.05, loss='deviance', max_depth=5,
#               max_features=23, max_leaf_nodes=None,
#               min_impurity_split=1e-07, min_samples_leaf=1,
#               min_samples_split=2, min_weight_fraction_leaf=0.0,
#               n_estimators=223, presort='auto', random_state=10,
#               subsample=1.0, verbose=0, warm_start=False)

# %%
important_feat=gradientB.best_estimator_.feature_importances_

important_feature_plot(features,important_feat,'Gradient Boosting')

# %%
predictedgb=gradientB.predict(X_test1)

# %%
pd.crosstab(y_test,predictedgb,colnames=['predicted'],rownames=['Actual'])
# Out:
# predicted      0    1
# Actual
# 0          19959  271
# 1            908  988

# %%
#Accuracy score
metrics.accuracy_score(y_test,predictedgb)
# Out:
# 0.94671427280122933

# %%
# prob_gbm=gradientB.predict_proba(X_test1)[:,1]
# plt.subplot(211)
# distprob(prob_gbm,0.5,model='Gradient Boosting')
# plt.subplot(212)
# distprob(prob_gbm,0.2,model='Gradient Boosting', adjusted=True)

# %%
prob_gbm=gradientB.predict_proba(X_test1)[:,1]

distprob(prob_gbm,0.5,model='Gradient Boosting')

# %%
prob_gbm=gradientB.predict_proba(X_test1)[:,1]

distprob(prob_gbm,0.4,model='Gradient Boosting', adjusted=True)

# %%
adjustpredgb=np.where(prob_gbm>0.4,1,0)
pd.crosstab(y_test,adjustpredgb,colnames=['Predicted'],rownames=['Actual'])
# Out:
# Predicted      0     1
# Actual
# 0          19836   394
# 1            824  1072

# %% [markdown]
# ### ROC Curve

# %%
def roc_curve(actual,score,model=''):
    fpr,tpr,thresholds=metrics.roc_curve(actual,score)
    plt.plot(fpr,tpr,label=model)
    plt.title('ROC curves')
    plt.xlabel('False postive rate')
    plt.ylabel('True positive rate')
    
roc_curve(y_test,predprob,'logistic')
plt.hold('on')
roc_curve(y_test,prob_rf,'Random Forest')
plt.hold('on')
roc_curve(y_test,prob_gbm,'Gradient Boosting')
plt.hold('off')
plt.legend(loc='lower right')

# %% [markdown]
# ### Specificity and sensitivity of models

# %%
model_predictions=[predicted,predicted_rf,predictedgb]
print('Summary of model performance')
for i,pred in enumerate(model_predictions):
    if i == 1:
        print("For Logistic model")
    elif i == 2:
        print('For random forest')
    else:
        print('for gradient boosting')
        
    print(metrics.classification_report(y_test,pred))
    print('\n')
# Out:
# Summary of model performance
# for gradient boosting
#              precision    recall  f1-score   support
#
#           0       0.98      0.88      0.93     20230
#           1       0.38      0.78      0.51      1896
#
# avg / total       0.93      0.87      0.89     22126
#
#
#
# For Logistic model
#              precision    recall  f1-score   support
#
#           0       0.95      0.99      0.97     20230
#           1       0.80      0.46      0.59      1896
#
# avg / total       0.94      0.94      0.94     22126
#
#
#
# For random forest
#              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.97     20230
#           1       0.78      0.52      0.63      1896
#
# avg / total       0.94      0.95      0.94     22126

# %% [markdown]
# ### Writing out predictions to disk

# %%
results=pd.DataFrame({'Logistic':predicted,'Random_forest':predicted_rf,'Gradient_Boosting':predictedgb})
# results.to_csv('C:\\Users\\senatoduro8\\Poverty_center\\Predictions.csv')
results.to_csv('Z:/largetransfer/luc/carter/Isaac//Predictions_10_14_2016.csv')

# %% [markdown]
# ### Files for buffering

# %%
predictions=pd.read_csv('Z:/largetransfer/luc/carter/data/predictions/Predictions_10_14_2016.csv')

# %%
X_test.reset_index(inplace=True)

# %%
# data=pd.merge(pd.DataFrame(y_test).reset_index(),predictions,right_index=True,left_index=True,how='inner').drop('Unnamed: 0',axis=1)
df=pd.merge(data,X_test[['parcel','NAME10','Survey Grade']],left_on='parcel',right_on='parcel',how='outer').rename(columns={'NAME10':'census_track'})

# %%
df.to_csv('Z:/largetransfer/luc/carter/data/predictions/predictions_10_14_2016.csv')
